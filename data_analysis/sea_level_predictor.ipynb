# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import linregress
import numpy as np

# %%
df= pd.read_csv('epa-sea-level.csv', index_col='Year')

# %%
df
# Out:
#       CSIRO Adjusted Sea Level  Lower Error Bound  Upper Error Bound  \
# Year
# 1880                  0.000000          -0.952756           0.952756
# 1881                  0.220472          -0.732283           1.173228
# 1882                 -0.440945          -1.346457           0.464567
# 1883                 -0.232283          -1.129921           0.665354
# 1884                  0.590551          -0.283465           1.464567
# ...                        ...                ...                ...
# 2009                  8.586614           8.311024           8.862205
# 2010                  8.901575           8.618110           9.185039
# 2011                  8.964567           8.661417           9.267717
# 2012                  9.326772           8.992126           9.661417
# 2013                  8.980315           8.622047           9.338583
#
#       NOAA Adjusted Sea Level
# Year
# 1880                      NaN
# 1881                      NaN
# 1882                      NaN
# ...

# %%
fig, ax = plt.subplots(figsize=(12,5), dpi=100)
ax.scatter(x=df.index, y=df['CSIRO Adjusted Sea Level'], color='red', s=1)
ax.set_xlabel('Year')
ax.set_ylabel('Sea Level (inches)')
ax.set_title('Rise in Sea Level')
#df.plot.scatter(x=index, y='CSIRO Adjusted Sea Level')
# Out:
# Text(0.5, 1.0, 'Rise in Sea Level')

# %%
stats=linregress(x=df.index, y=df['CSIRO Adjusted Sea Level'])

# %%
def f(x):
    return x * stats.slope + stats.intercept

x=np.arange(1880,2050,1)
y=f(x)

# %%
ax.plot(x,y)
fig
